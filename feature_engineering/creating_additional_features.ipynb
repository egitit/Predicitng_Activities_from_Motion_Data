# %%
import pandas as pd
import numpy as np
file = '/Users/Lisa/_Sports_Activity_Capstone/updated_df_with_times.csv'
df = pd.read_csv(file)
df.drop('Unnamed: 0', axis=1, inplace=True)
# %run update_names.ipynb
df
# Out:
#          person  activity_number  time    T_xacc   T_yacc   T_zacc   T_xgyro  \
# 0             1                1   1.0   8.13050  1.03490  5.42170 -0.009461
# 1             1                1   1.0   8.13050  1.02020  5.38430 -0.009368
# 2             1                1   1.0   8.16040  1.02010  5.36220  0.015046
# 3             1                1   1.0   8.16030  1.00520  5.37700  0.006892
# 4             1                1   1.0   8.16050  1.02750  5.34730  0.008811
# ...         ...              ...   ...       ...      ...      ...       ...
# 1139995       8               19   5.0  16.00800 -2.01660 -0.58220  2.027100
# 1139996       8               19   5.0   8.28230 -0.69936  0.48698  2.887900
# 1139997       8               19   5.0   2.71210  0.49967  0.84053  1.996400
# 1139998       8               19   5.0   2.03080 -0.71349 -0.11264  1.766100
# 1139999       8               19   5.0  -0.04915  0.76302 -0.19343  2.590200
#
# ...

# %% [markdown]
# ## Create a group_min_data csv

# %%
grouped_min_data = df.groupby(['person', 'activity_number', 'time']).min()

# %%
update_names(grouped_min_data, "_min")
# Out:
#                              T_xacc_min  T_yacc_min  T_zacc_min  T_xgyro_min  \
# person activity_number time
# 1      1               1.0       7.6304     0.99744      5.1551    -0.044333
#                        2.0       7.6674     1.09330      5.1934    -0.076602
#                        3.0       7.5779     1.09320      5.3307    -0.089536
#                        4.0       7.6150     1.32750      5.2069    -0.057806
#                        5.0       7.6008     1.35780      5.3313    -0.048362
# ...                                 ...         ...         ...          ...
# 8      19              1.0      -4.4558   -10.12000    -11.3990    -8.220900
#                        2.0      -6.6837   -15.38400    -13.2250   -15.241000
#                        3.0      -5.0091   -15.48500    -17.2110   -12.916000
#                        4.0      -7.5391   -19.45300    -15.9590    -8.530300
#                        5.0     -12.8920   -11.76400    -19.9410   -15.905000
#
# ...

# %%
# Commenting out to prevent multiple csvs being created
# grouped_min_data.to_csv("grouped_min_data.csv")

# %% [markdown]
# ## Create a group_max_data csv

# %%
grouped_max_data = df.groupby(['person', 'activity_number', 'time']).max()

# %%
update_names(grouped_max_data, "_max")
# Out:
#                              T_xacc_max  T_yacc_max  T_zacc_max  T_xgyro_max  \
# person activity_number time
# 1      1               1.0       8.1763      1.3232      6.1814     0.052515
#                        2.0       8.1156      1.4182      6.0415     0.053855
#                        3.0       8.0264      1.5356      6.2569     0.057326
#                        4.0       8.1154      1.5501      6.1397     0.046308
#                        5.0       8.1009      1.6830      6.0164     0.075330
# ...                                 ...         ...         ...          ...
# 8      19              1.0      41.9120     16.9700     50.3720     5.526800
#                        2.0      52.6440     11.3650     36.0910     7.289600
#                        3.0      51.4080     15.7040     46.0790     7.171100
#                        4.0      39.5820     15.6790     73.8090     7.356800
#                        5.0      72.7820     14.1470     46.5790    10.475000
#
# ...

# %%
# Commenting out to prevent multiple csvs being created
#grouped_max_data.to_csv('grouped_max_data.csv')

# %% [markdown]
# ## Create a group_median_data csv

# %%
grouped_median_data = df.groupby(['person', 'activity_number', 'time']).median()

# %%
update_names(grouped_median_data, "_median")
# Out:
#                              T_xacc_median  T_yacc_median  T_zacc_median  \
# person activity_number time
# 1      1               1.0         7.92150       1.168400       5.670000
#                        2.0         7.87670       1.270500       5.711600
#                        3.0         7.81695       1.328700       5.775550
#                        4.0         7.83225       1.445750       5.735100
#                        5.0         7.83185       1.490200       5.718200
# ...                                    ...            ...            ...
# 8      19              1.0         9.47935      -0.188765       0.868535
#                        2.0         9.57375      -0.069448       0.906300
#                        3.0         9.34075      -0.083682       1.122550
#                        4.0         9.32395      -0.254025       0.566380
#                        5.0         9.17935      -0.190950       0.835690
#
# ...

# %%
# Commenting out to prevent multiple csvs being created
#grouped_median_data.to_csv("grouped_median_data.csv")

# %% [markdown]
# ## Create a group_variance_data csv

# %%
grouped_variance_data = df.groupby(['person', 'activity_number', 'time']).var()

# %%
update_names(grouped_variance_data, "_variance")
# Out:
#                              T_xacc_variance  T_yacc_variance  \
# person activity_number time
# 1      1               1.0          0.005741         0.002339
#                        2.0          0.004102         0.001865
#                        3.0          0.004223         0.003275
#                        4.0          0.004859         0.001235
#                        5.0          0.003466         0.002267
# ...                                      ...              ...
# 8      19              1.0         20.346031         5.434005
#                        2.0         29.010929         5.839315
#                        3.0         29.027454         6.393135
#                        4.0         21.914694         9.160095
#                        5.0         36.549750         6.307192
#
#                              T_zacc_variance  T_xgyro_variance  \
# person activity_number time
# 1      1               1.0          0.012997          0.000178
# ...

# %%
# Commenting out to prevent multiple csvs being created
#grouped_variance_data.to_csv("grouped_variance_data.csv")

# %% [markdown]
# ## Create a group_std_data csv

# %%
grouped_std_data = df.groupby(['person', 'activity_number', 'time']).std()

# %%
update_names(grouped_std_data, "_std")
# Out:
#                              T_xacc_std  T_yacc_std  T_zacc_std  T_xgyro_std  \
# person activity_number time
# 1      1               1.0     0.075770    0.048362    0.114005     0.013342
#                        2.0     0.064047    0.043183    0.105624     0.014663
#                        3.0     0.064984    0.057230    0.101143     0.014081
#                        4.0     0.069708    0.035138    0.107584     0.012608
#                        5.0     0.058875    0.047616    0.091718     0.013428
# ...                                 ...         ...         ...          ...
# 8      19              1.0     4.510658    2.331095    2.815867     1.181631
#                        2.0     5.386179    2.416467    3.044239     1.417473
#                        3.0     5.387713    2.528465    3.587029     1.473090
#                        4.0     4.681313    3.026565    4.207847     1.405514
#                        5.0     6.045639    2.511412    3.524716     1.728276
#
# ...

# %%
# Commenting out to prevent multiple csvs being created
#grouped_std_data.to_csv("grouped_std_data.csv")

# %% [markdown]
# ## Create a group_sum_data csv

# %%
grouped_sum_data = df.groupby(['person', 'activity_number', 'time']).sum()

# %%
update_names(grouped_sum_data, "_sum")
# Out:
#                                T_xacc_sum   T_yacc_sum   T_zacc_sum  \
# person activity_number time
# 1      1               1.0   11895.816700  1753.643010  8481.803600
#                        2.0   11824.832900  1907.491500  8550.088100
#                        3.0   11737.689400  2011.174900  8649.479300
#                        4.0   11757.353600  2163.585600  8586.358500
#                        5.0   11758.970600  2246.555700  8563.325600
# ...                                   ...          ...          ...
# 8      19              1.0   14336.476534  -405.371204  1334.613313
#                        2.0   14315.498278  -385.366046  1626.945150
#                        3.0   14267.873809  -302.878310  1612.766972
#                        4.0   14063.832267  -804.345279   544.555429
#                        5.0   14147.074275  -412.475464   830.770534
#
#                              T_xgyro_sum  T_ygyro_sum  T_zgyro_sum  \
# person activity_number time
# ...

# %%
# Commenting out to prevent multiple csvs being created
#grouped_sum_data.to_csv("grouped_sum_data.csv")
