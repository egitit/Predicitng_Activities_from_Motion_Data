# %%
# %run my_cross_val_score.ipynb
# Out:
# Testing set (1, 2) scored: 0.95
# Testing set (1, 3) scored: 0.98
# Testing set (1, 4) scored: 0.96
# Testing set (1, 5) scored: 0.97
# Testing set (1, 6) scored: 0.99
# Testing set (1, 7) scored: 0.96
# Testing set (1, 8) scored: 0.98
# Testing set (2, 3) scored: 0.93
# Testing set (2, 4) scored: 0.94
# Testing set (2, 5) scored: 0.95
# Testing set (2, 6) scored: 0.95
# Testing set (2, 7) scored: 0.94
# Testing set (2, 8) scored: 0.92
# Testing set (3, 4) scored: 0.97
# Testing set (3, 5) scored: 0.95
# Testing set (3, 6) scored: 0.97
# Testing set (3, 7) scored: 0.93
# Testing set (3, 8) scored: 0.97
# Testing set (4, 5) scored: 0.96
# Testing set (4, 6) scored: 0.97
# Testing set (4, 7) scored: 0.95
# Testing set (4, 8) scored: 0.96
# Testing set (5, 6) scored: 0.96
# Testing set (5, 7) scored: 0.97
# Testing set (5, 8) scored: 0.97
# Testing set (6, 7) scored: 0.96
# Testing set (6, 8) scored: 0.98
# Testing set (7, 8) scored: 0.94

# %%
def cleaned_up(df_name):
    testing_sets, scores = my_cross_val_score(df_name)
    avg = (sum(scores) / len(scores)).round(3)
    for x in range(0, len(testing_sets)):
        print(f"Testing set {testing_sets[x]} scored: {scores[x].round(2)}")
    print(f"The score range was: {(max(scores) - min(scores)).round(2)}")
    print(f"The average score of the testing is: {avg}")
    return avg

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
# Worst to best scores:
cleaned_up(torso)
# Out:
# Testing set (1, 2) scored: 0.59
# Testing set (1, 3) scored: 0.58
# Testing set (1, 4) scored: 0.58
# Testing set (1, 5) scored: 0.54
# Testing set (1, 6) scored: 0.57
# Testing set (1, 7) scored: 0.57
# Testing set (1, 8) scored: 0.57
# Testing set (2, 3) scored: 0.5
# Testing set (2, 4) scored: 0.46
# Testing set (2, 5) scored: 0.55
# Testing set (2, 6) scored: 0.59
# Testing set (2, 7) scored: 0.54
# Testing set (2, 8) scored: 0.52
# Testing set (3, 4) scored: 0.5
# Testing set (3, 5) scored: 0.53
# Testing set (3, 6) scored: 0.59
# Testing set (3, 7) scored: 0.48
# Testing set (3, 8) scored: 0.41
# Testing set (4, 5) scored: 0.55
# Testing set (4, 6) scored: 0.57
# Testing set (4, 7) scored: 0.52
# Testing set (4, 8) scored: 0.48
# Testing set (5, 6) scored: 0.62
# Testing set (5, 7) scored: 0.54
# Testing set (5, 8) scored: 0.52
# Testing set (6, 7) scored: 0.55
# Testing set (6, 8) scored: 0.56
# Testing set (7, 8) scored: 0.49
# The score range was: 0.21
# The average score of the testing is: 0.539
# 0.539

# %%
cleaned_up(arms)
# Out:
# Testing set (1, 2) scored: 0.75
# Testing set (1, 3) scored: 0.74
# Testing set (1, 4) scored: 0.76
# Testing set (1, 5) scored: 0.76
# Testing set (1, 6) scored: 0.63
# Testing set (1, 7) scored: 0.75
# Testing set (1, 8) scored: 0.68
# Testing set (2, 3) scored: 0.74
# Testing set (2, 4) scored: 0.81
# Testing set (2, 5) scored: 0.77
# Testing set (2, 6) scored: 0.69
# Testing set (2, 7) scored: 0.7
# Testing set (2, 8) scored: 0.7
# Testing set (3, 4) scored: 0.8
# Testing set (3, 5) scored: 0.76
# Testing set (3, 6) scored: 0.76
# Testing set (3, 7) scored: 0.75
# Testing set (3, 8) scored: 0.71
# Testing set (4, 5) scored: 0.79
# Testing set (4, 6) scored: 0.77
# Testing set (4, 7) scored: 0.75
# Testing set (4, 8) scored: 0.76
# Testing set (5, 6) scored: 0.77
# Testing set (5, 7) scored: 0.77
# Testing set (5, 8) scored: 0.74
# Testing set (6, 7) scored: 0.7
# Testing set (6, 8) scored: 0.68
# Testing set (7, 8) scored: 0.69
# The score range was: 0.18
# The average score of the testing is: 0.739
# 0.739

# %%
cleaned_up(legs)
# Out:
# Testing set (1, 2) scored: 0.84
# Testing set (1, 3) scored: 0.83
# Testing set (1, 4) scored: 0.89
# Testing set (1, 5) scored: 0.83
# Testing set (1, 6) scored: 0.82
# Testing set (1, 7) scored: 0.85
# Testing set (1, 8) scored: 0.78
# Testing set (2, 3) scored: 0.75
# Testing set (2, 4) scored: 0.82
# Testing set (2, 5) scored: 0.65
# Testing set (2, 6) scored: 0.75
# Testing set (2, 7) scored: 0.79
# Testing set (2, 8) scored: 0.75
# Testing set (3, 4) scored: 0.84
# Testing set (3, 5) scored: 0.73
# Testing set (3, 6) scored: 0.76
# Testing set (3, 7) scored: 0.81
# Testing set (3, 8) scored: 0.75
# Testing set (4, 5) scored: 0.83
# Testing set (4, 6) scored: 0.82
# Testing set (4, 7) scored: 0.89
# Testing set (4, 8) scored: 0.81
# Testing set (5, 6) scored: 0.75
# Testing set (5, 7) scored: 0.79
# Testing set (5, 8) scored: 0.78
# Testing set (6, 7) scored: 0.85
# Testing set (6, 8) scored: 0.79
# Testing set (7, 8) scored: 0.83
# The score range was: 0.24
# The average score of the testing is: 0.799
# 0.799

# %%
#Combo1
cleaned_up(combo_df)
# Out:
# Testing set (1, 2) scored: 0.69
# Testing set (1, 3) scored: 0.71
# Testing set (1, 4) scored: 0.71
# Testing set (1, 5) scored: 0.67
# Testing set (1, 6) scored: 0.69
# Testing set (1, 7) scored: 0.67
# Testing set (1, 8) scored: 0.66
# Testing set (2, 3) scored: 0.76
# Testing set (2, 4) scored: 0.73
# Testing set (2, 5) scored: 0.73
# Testing set (2, 6) scored: 0.78
# Testing set (2, 7) scored: 0.72
# Testing set (2, 8) scored: 0.78
# Testing set (3, 4) scored: 0.8
# Testing set (3, 5) scored: 0.73
# Testing set (3, 6) scored: 0.81
# Testing set (3, 7) scored: 0.72
# Testing set (3, 8) scored: 0.77
# Testing set (4, 5) scored: 0.7
# Testing set (4, 6) scored: 0.77
# Testing set (4, 7) scored: 0.73
# Testing set (4, 8) scored: 0.67
# Testing set (5, 6) scored: 0.79
# Testing set (5, 7) scored: 0.76
# Testing set (5, 8) scored: 0.69
# Testing set (6, 7) scored: 0.74
# Testing set (6, 8) scored: 0.72
# Testing set (7, 8) scored: 0.76
# The score range was: 0.15
# The average score of the testing is: 0.731
# 0.731

# %%
# Combo2 df
cleaned_up(df)
# Out:
# Testing set (1, 2) scored: 0.82
# Testing set (1, 3) scored: 0.84
# Testing set (1, 4) scored: 0.9
# Testing set (1, 5) scored: 0.83
# Testing set (1, 6) scored: 0.81
# Testing set (1, 7) scored: 0.84
# Testing set (1, 8) scored: 0.79
# Testing set (2, 3) scored: 0.78
# Testing set (2, 4) scored: 0.86
# Testing set (2, 5) scored: 0.81
# Testing set (2, 6) scored: 0.82
# Testing set (2, 7) scored: 0.86
# Testing set (2, 8) scored: 0.81
# Testing set (3, 4) scored: 0.95
# Testing set (3, 5) scored: 0.84
# Testing set (3, 6) scored: 0.9
# Testing set (3, 7) scored: 0.87
# Testing set (3, 8) scored: 0.85
# Testing set (4, 5) scored: 0.85
# Testing set (4, 6) scored: 0.91
# Testing set (4, 7) scored: 0.92
# Testing set (4, 8) scored: 0.84
# Testing set (5, 6) scored: 0.8
# Testing set (5, 7) scored: 0.88
# Testing set (5, 8) scored: 0.79
# Testing set (6, 7) scored: 0.86
# Testing set (6, 8) scored: 0.82
# Testing set (7, 8) scored: 0.84
# The score range was: 0.16
# The average score of the testing is: 0.845
# 0.845

# %%
cleaned_up(df_var)
# Out:
# Testing set (1, 2) scored: 0.89
# Testing set (1, 3) scored: 0.87
# Testing set (1, 4) scored: 0.93
# Testing set (1, 5) scored: 0.91
# Testing set (1, 6) scored: 0.91
# Testing set (1, 7) scored: 0.92
# Testing set (1, 8) scored: 0.84
# Testing set (2, 3) scored: 0.87
# Testing set (2, 4) scored: 0.89
# Testing set (2, 5) scored: 0.92
# Testing set (2, 6) scored: 0.89
# Testing set (2, 7) scored: 0.9
# Testing set (2, 8) scored: 0.83
# Testing set (3, 4) scored: 0.81
# Testing set (3, 5) scored: 0.82
# Testing set (3, 6) scored: 0.89
# Testing set (3, 7) scored: 0.8
# Testing set (3, 8) scored: 0.82
# Testing set (4, 5) scored: 0.91
# Testing set (4, 6) scored: 0.86
# Testing set (4, 7) scored: 0.87
# Testing set (4, 8) scored: 0.78
# Testing set (5, 6) scored: 0.9
# Testing set (5, 7) scored: 0.85
# Testing set (5, 8) scored: 0.85
# Testing set (6, 7) scored: 0.87
# Testing set (6, 8) scored: 0.86
# Testing set (7, 8) scored: 0.78
# The score range was: 0.15
# The average score of the testing is: 0.866
# 0.866

# %%
cleaned_up(df_std)
# Out:
# Testing set (1, 2) scored: 0.91
# Testing set (1, 3) scored: 0.91
# Testing set (1, 4) scored: 0.94
# Testing set (1, 5) scored: 0.92
# Testing set (1, 6) scored: 0.91
# Testing set (1, 7) scored: 0.89
# Testing set (1, 8) scored: 0.85
# Testing set (2, 3) scored: 0.87
# Testing set (2, 4) scored: 0.9
# Testing set (2, 5) scored: 0.87
# Testing set (2, 6) scored: 0.89
# Testing set (2, 7) scored: 0.92
# Testing set (2, 8) scored: 0.85
# Testing set (3, 4) scored: 0.81
# Testing set (3, 5) scored: 0.83
# Testing set (3, 6) scored: 0.88
# Testing set (3, 7) scored: 0.85
# Testing set (3, 8) scored: 0.83
# Testing set (4, 5) scored: 0.92
# Testing set (4, 6) scored: 0.88
# Testing set (4, 7) scored: 0.89
# Testing set (4, 8) scored: 0.78
# Testing set (5, 6) scored: 0.93
# Testing set (5, 7) scored: 0.85
# Testing set (5, 8) scored: 0.79
# Testing set (6, 7) scored: 0.88
# Testing set (6, 8) scored: 0.88
# Testing set (7, 8) scored: 0.79
# The score range was: 0.15
# The average score of the testing is: 0.872
# 0.872

# %%
cleaned_up(combo2_and_var)
# Out:
# Testing set (1, 2) scored: 0.97
# Testing set (1, 3) scored: 0.97
# Testing set (1, 4) scored: 0.97
# Testing set (1, 5) scored: 0.97
# Testing set (1, 6) scored: 0.99
# Testing set (1, 7) scored: 0.96
# Testing set (1, 8) scored: 0.99
# Testing set (2, 3) scored: 0.93
# Testing set (2, 4) scored: 0.95
# Testing set (2, 5) scored: 0.92
# Testing set (2, 6) scored: 0.95
# Testing set (2, 7) scored: 0.95
# Testing set (2, 8) scored: 0.94
# Testing set (3, 4) scored: 0.96
# Testing set (3, 5) scored: 0.95
# Testing set (3, 6) scored: 0.99
# Testing set (3, 7) scored: 0.95
# Testing set (3, 8) scored: 0.97
# Testing set (4, 5) scored: 0.95
# Testing set (4, 6) scored: 0.97
# Testing set (4, 7) scored: 0.95
# Testing set (4, 8) scored: 0.95
# Testing set (5, 6) scored: 0.97
# Testing set (5, 7) scored: 0.97
# Testing set (5, 8) scored: 0.98
# Testing set (6, 7) scored: 0.97
# Testing set (6, 8) scored: 0.99
# Testing set (7, 8) scored: 0.95
# The score range was: 0.08
# The average score of the testing is: 0.962
# 0.962

# %%
cleaned_up(legs_and_var)
# Out:
# Testing set (1, 2) scored: 0.97
# Testing set (1, 3) scored: 0.97
# Testing set (1, 4) scored: 0.97
# Testing set (1, 5) scored: 1.0
# Testing set (1, 6) scored: 0.99
# Testing set (1, 7) scored: 0.96
# Testing set (1, 8) scored: 0.99
# Testing set (2, 3) scored: 0.94
# Testing set (2, 4) scored: 0.94
# Testing set (2, 5) scored: 0.94
# Testing set (2, 6) scored: 0.93
# Testing set (2, 7) scored: 0.94
# Testing set (2, 8) scored: 0.93
# Testing set (3, 4) scored: 0.95
# Testing set (3, 5) scored: 0.95
# Testing set (3, 6) scored: 0.98
# Testing set (3, 7) scored: 0.93
# Testing set (3, 8) scored: 0.98
# Testing set (4, 5) scored: 0.96
# Testing set (4, 6) scored: 0.98
# Testing set (4, 7) scored: 0.93
# Testing set (4, 8) scored: 0.94
# Testing set (5, 6) scored: 0.96
# Testing set (5, 7) scored: 0.96
# Testing set (5, 8) scored: 0.98
# Testing set (6, 7) scored: 0.96
# Testing set (6, 8) scored: 0.98
# Testing set (7, 8) scored: 0.92
# The score range was: 0.08
# The average score of the testing is: 0.958
# 0.958
