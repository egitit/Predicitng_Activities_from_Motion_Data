# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
# %run subplot_func.ipynb

# %%
file = '/Users/Lisa/_Sports_Activity_Capstone/df_with_times.csv'

# %%
df = pd.read_csv(file)

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#          person  activity_number    time    T_xacc   T_yacc   T_zacc  \
# 0             1                1    0.04   8.13050  1.03490  5.42170
# 1             1                1    0.08   8.13050  1.02020  5.38430
# 2             1                1    0.12   8.16040  1.02010  5.36220
# 3             1                1    0.16   8.16030  1.00520  5.37700
# 4             1                1    0.20   8.16050  1.02750  5.34730
# ...         ...              ...     ...       ...      ...      ...
# 1139995       8               19  299.84  16.00800 -2.01660 -0.58220
# 1139996       8               19  299.88   8.28230 -0.69936  0.48698
# 1139997       8               19  299.92   2.71210  0.49967  0.84053
# 1139998       8               19  299.96   2.03080 -0.71349 -0.11264
# 1139999       8               19  300.00  -0.04915  0.76302 -0.19343
#
#           T_xgyro   T_ygyro   T_zgyro   T_xmag  ...   RL_zmag  LL_xacc  \
# ...

# %% [markdown]
# # Conducting EDA on participant 4

# %% [markdown]
# ## Activity 1 - sitting

# %%
make_user_subplots(df, 'T_xacc', 1, 4)
make_user_subplots(df, 'T_yacc', 1, 4)
make_user_subplots(df, 'T_zacc', 1, 4)

# %% [markdown]
# ## Activity 9 - walking in a parking lot

# %%
make_user_subplots(df, 'T_xacc', 9, 4)
make_user_subplots(df, 'T_yacc', 9, 4)
make_user_subplots(df, 'T_zacc', 9, 4)

# %% [markdown]
# ## Activity 19 - playing basketball

# %%
make_user_subplots(df, 'T_xacc', 19, 4)
make_user_subplots(df, 'T_yacc', 19, 4)
make_user_subplots(df, 'T_zacc', 19, 4)
