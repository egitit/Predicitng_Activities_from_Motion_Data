# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
# %run subplot_func.ipynb
file = '/Users/Lisa/_Sports_Activity_Capstone/df_with_times.csv'
df = pd.read_csv(file)
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# # Conducting EDA on participant 2

# %% [markdown]
# ## Activity 1 - sitting

# %%
make_user_subplots(df, 'T_xacc', 1, 2)
make_user_subplots(df, 'T_yacc', 1, 2)
make_user_subplots(df, 'T_zacc', 1, 2)

# %% [markdown]
# ## Activity 9 - walking in a parking lot

# %%
make_user_subplots(df, 'T_xacc', 9, 2)
make_user_subplots(df, 'T_yacc', 9, 2)
make_user_subplots(df, 'T_zacc', 9, 2)

# %% [markdown]
# ## Activity 19 - playing basketball

# %%
make_user_subplots(df, 'T_xacc', 19, 2)
make_user_subplots(df, 'T_yacc', 19, 2)
make_user_subplots(df, 'T_zacc', 19, 2)
