# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
file = '/Users/Lisa/_Sports_Activity_Capstone/complete_data_with_activities.csv'

# %%
df = pd.read_csv(file)

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#            T_xacc   T_yacc   T_zacc   T_xgyro   T_ygyro   T_zgyro   T_xmag  \
# 0         8.13050  1.03490  5.42170 -0.009461  0.001915 -0.003424 -0.78712
# 1         8.13050  1.02020  5.38430 -0.009368  0.023485  0.001953 -0.78717
# 2         8.16040  1.02010  5.36220  0.015046  0.014330  0.000204 -0.78664
# 3         8.16030  1.00520  5.37700  0.006892  0.018045  0.005649 -0.78529
# 4         8.16050  1.02750  5.34730  0.008811  0.030433 -0.005346 -0.78742
# ...           ...      ...      ...       ...       ...       ...      ...
# 1139995  16.00800 -2.01660 -0.58220  2.027100  1.656800  0.584410 -0.73195
# 1139996   8.28230 -0.69936  0.48698  2.887900  1.603900 -0.020417 -0.73055
# 1139997   2.71210  0.49967  0.84053  1.996400  1.465800 -0.072605 -0.72533
# 1139998   2.03080 -0.71349 -0.11264  1.766100  1.010300 -0.102120 -0.71933
# 1139999  -0.04915  0.76302 -0.19343  2.590200  0.179090  0.011850 -0.71592
#
# ...

# %%
ls = []

for i in range(1140000):
    p = i // 7500
    assignment = (p % 8) + 1
    ls.append(assignment)

ls = np.array(ls)

# %%
# Confirming that the people values are evenly distributed
Counter(ls)
# Out:
# Counter({1: 142500,
#          2: 142500,
#          3: 142500,
#          4: 142500,
#          5: 142500,
#          6: 142500,
#          7: 142500,
#          8: 142500})

# %%
persons = pd.DataFrame(ls, columns=['person'])

# %%
df['person'] = persons

# %%
new_order = ['person', 'activity_number', 'T_xacc', 'T_yacc', 'T_zacc', 'T_xgyro', 'T_ygyro', 'T_zgyro', 'T_xmag',
       'T_ymag', 'T_zmag', 'RA_xacc', 'RA_yacc', 'RA_zacc', 'RA_xgyro',
       'RA_ygyro', 'RA_zgyro', 'RA_xmag', 'RA_ymag', 'RA_zmag', 'LA_xacc',
       'LA_yacc', 'LA_zacc', 'LA_xgyro', 'LA_ygyro', 'LA_zgyro', 'LA_xmag',
       'LA_ymag', 'LA_zmag', 'RL_xacc', 'RL_yacc', 'RL_zacc', 'RL_xgyro',
       'RL_ygyro', 'RL_zgyro', 'RL_xmag', 'RL_ymag', 'RL_zmag', 'LL_xacc',
       'LL_yacc', 'LL_zacc', 'LL_xgyro', 'LL_ygyro', 'LL_zgyro', 'LL_xmag',
       'LL_ymag', 'LL_zmag'
            ]

# %%
df = df.reindex(columns=new_order)
df
# Out:
#          person  activity_number    T_xacc   T_yacc   T_zacc   T_xgyro  \
# 0             1                1   8.13050  1.03490  5.42170 -0.009461
# 1             1                1   8.13050  1.02020  5.38430 -0.009368
# 2             1                1   8.16040  1.02010  5.36220  0.015046
# 3             1                1   8.16030  1.00520  5.37700  0.006892
# 4             1                1   8.16050  1.02750  5.34730  0.008811
# ...         ...              ...       ...      ...      ...       ...
# 1139995       8               19  16.00800 -2.01660 -0.58220  2.027100
# 1139996       8               19   8.28230 -0.69936  0.48698  2.887900
# 1139997       8               19   2.71210  0.49967  0.84053  1.996400
# 1139998       8               19   2.03080 -0.71349 -0.11264  1.766100
# 1139999       8               19  -0.04915  0.76302 -0.19343  2.590200
#
#           T_ygyro   T_zgyro   T_xmag    T_ymag  ...   RL_zmag  LL_xacc  \
# ...

# %%
# create csv that has a new column with person added per activity for test_train_split in the future
# i.e. train = people 1-6, test will be person 7 & 8 or howevery I decide to break up the data
# df.to_csv('complete_data_with_activities_and_people.csv')
# CSV created - commenting out for future runs
