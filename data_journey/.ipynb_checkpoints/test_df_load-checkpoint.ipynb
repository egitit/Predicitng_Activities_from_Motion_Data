# %%
import pandas as pd

# %%
file = '/Users/Lisa/_Sports_Activity_Capstone/complete_data_with_activities.csv'

# %%
# Load the complete data with activities csv
df = pd.read_csv(file)

# %%
# Drop unnecessary column from csv import
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Test to be sure that the activity count is evenly distributed 
df.groupby('activity_number').count()
# Out:
#                  T_xacc  T_yacc  T_zacc  T_xgyro  T_ygyro  T_zgyro  T_xmag  \
# activity_number
# 1                 60000   60000   60000    60000    60000    60000   60000
# 2                 60000   60000   60000    60000    60000    60000   60000
# 3                 60000   60000   60000    60000    60000    60000   60000
# 4                 60000   60000   60000    60000    60000    60000   60000
# 5                 60000   60000   60000    60000    60000    60000   60000
# 6                 60000   60000   60000    60000    60000    60000   60000
# 7                 60000   60000   60000    60000    60000    60000   60000
# 8                 60000   60000   60000    60000    60000    60000   60000
# 9                 60000   60000   60000    60000    60000    60000   60000
# 10                60000   60000   60000    60000    60000    60000   60000
# 11                60000   60000   60000    60000    60000    60000   60000
# ...

# %%
# Check out the dataframe.
df
# Looks good!
# Out:
#            T_xacc   T_yacc   T_zacc   T_xgyro   T_ygyro   T_zgyro   T_xmag  \
# 0         8.13050  1.03490  5.42170 -0.009461  0.001915 -0.003424 -0.78712
# 1         8.13050  1.02020  5.38430 -0.009368  0.023485  0.001953 -0.78717
# 2         8.16040  1.02010  5.36220  0.015046  0.014330  0.000204 -0.78664
# 3         8.16030  1.00520  5.37700  0.006892  0.018045  0.005649 -0.78529
# 4         8.16050  1.02750  5.34730  0.008811  0.030433 -0.005346 -0.78742
# ...           ...      ...      ...       ...       ...       ...      ...
# 1139995  16.00800 -2.01660 -0.58220  2.027100  1.656800  0.584410 -0.73195
# 1139996   8.28230 -0.69936  0.48698  2.887900  1.603900 -0.020417 -0.73055
# 1139997   2.71210  0.49967  0.84053  1.996400  1.465800 -0.072605 -0.72533
# 1139998   2.03080 -0.71349 -0.11264  1.766100  1.010300 -0.102120 -0.71933
# 1139999  -0.04915  0.76302 -0.19343  2.590200  0.179090  0.011850 -0.71592
#
# ...
