# %%
import pandas as pd
import numpy as np
import random

# %%
file = '/Users/Lisa/_Sports_Activity_Capstone/df_with_times.csv'

# %%
df = pd.read_csv(file)
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#          person  activity_number    time    T_xacc   T_yacc   T_zacc  \
# 0             1                1    0.04   8.13050  1.03490  5.42170
# 1             1                1    0.08   8.13050  1.02020  5.38430
# 2             1                1    0.12   8.16040  1.02010  5.36220
# 3             1                1    0.16   8.16030  1.00520  5.37700
# 4             1                1    0.20   8.16050  1.02750  5.34730
# ...         ...              ...     ...       ...      ...      ...
# 1139995       8               19  299.84  16.00800 -2.01660 -0.58220
# 1139996       8               19  299.88   8.28230 -0.69936  0.48698
# 1139997       8               19  299.92   2.71210  0.49967  0.84053
# 1139998       8               19  299.96   2.03080 -0.71349 -0.11264
# 1139999       8               19  300.00  -0.04915  0.76302 -0.19343
#
#           T_xgyro   T_ygyro   T_zgyro   T_xmag  ...   RL_zmag  LL_xacc  \
# ...

# %%
y = df['activity_number']
y
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#            ..
# 1139995    19
# 1139996    19
# 1139997    19
# 1139998    19
# 1139999    19
# Name: activity_number, Length: 1140000, dtype: int64

# %%
X = df.drop('activity_number', axis=1)
X
# Out:
#          person    time    T_xacc   T_yacc   T_zacc   T_xgyro   T_ygyro  \
# 0             1    0.04   8.13050  1.03490  5.42170 -0.009461  0.001915
# 1             1    0.08   8.13050  1.02020  5.38430 -0.009368  0.023485
# 2             1    0.12   8.16040  1.02010  5.36220  0.015046  0.014330
# 3             1    0.16   8.16030  1.00520  5.37700  0.006892  0.018045
# 4             1    0.20   8.16050  1.02750  5.34730  0.008811  0.030433
# ...         ...     ...       ...      ...      ...       ...       ...
# 1139995       8  299.84  16.00800 -2.01660 -0.58220  2.027100  1.656800
# 1139996       8  299.88   8.28230 -0.69936  0.48698  2.887900  1.603900
# 1139997       8  299.92   2.71210  0.49967  0.84053  1.996400  1.465800
# 1139998       8  299.96   2.03080 -0.71349 -0.11264  1.766100  1.010300
# 1139999       8  300.00  -0.04915  0.76302 -0.19343  2.590200  0.179090
#
#           T_zgyro   T_xmag    T_ymag  ...   RL_zmag  LL_xacc  LL_yacc  \
# ...

# %%
# Way to 
random_values = random.sample(range(1,9), 6)
df['person'].isin(random_values)
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#            ...
# 1139995    True
# 1139996    True
# 1139997    True
# 1139998    True
# 1139999    True
# Name: person, Length: 1140000, dtype: bool

# %%
def my_train_test_split(X, y):
    '''
    Create a custom train_test_split function to split my data accordingly.
    Creating since my data needs to be specifically sliced 
    i.e.
    - participants 1-6 = training data
    - participants 7-8 = testing data
    
    Parameters:
    X: features
    y: target values
    
    returns:
    X_train, X_test, y_train, y_test, random_values
    '''
    random_values = random.sample(range(1,9), 6)
    mask = df['person'].isin(random_values)
    X_train = X[mask]
    X_test = X[~mask]
    y_train = y[mask]
    y_test = y[~mask]
    return X_train, X_test, y_train, y_test, random_values

# %%
X_train, X_test, y_train, y_test, random_values = my_train_test_split(X, y)

# %%
random_values
# Out:
# [8, 7, 5, 6, 2, 1]

# %%
# Testing for training data
print(855000/1140000)
X_train
# Out:
# 0.75
#          person    time    T_xacc   T_yacc   T_zacc   T_xgyro   T_ygyro  \
# 0             1    0.04   8.13050  1.03490  5.42170 -0.009461  0.001915
# 1             1    0.08   8.13050  1.02020  5.38430 -0.009368  0.023485
# 2             1    0.12   8.16040  1.02010  5.36220  0.015046  0.014330
# 3             1    0.16   8.16030  1.00520  5.37700  0.006892  0.018045
# 4             1    0.20   8.16050  1.02750  5.34730  0.008811  0.030433
# ...         ...     ...       ...      ...      ...       ...       ...
# 1139995       8  299.84  16.00800 -2.01660 -0.58220  2.027100  1.656800
# 1139996       8  299.88   8.28230 -0.69936  0.48698  2.887900  1.603900
# 1139997       8  299.92   2.71210  0.49967  0.84053  1.996400  1.465800
# 1139998       8  299.96   2.03080 -0.71349 -0.11264  1.766100  1.010300
# 1139999       8  300.00  -0.04915  0.76302 -0.19343  2.590200  0.179090
#
#           T_zgyro   T_xmag    T_ymag  ...   RL_zmag  LL_xacc  LL_yacc  \
# ...

# %%
# Testing for testing data
print(285000/1140000)
X_test
# Out:
# 0.25
#          person    time   T_xacc   T_yacc  T_zacc   T_xgyro   T_ygyro  \
# 15000         3    0.04   9.0356 -1.51970  3.5627  0.029486 -0.010331
# 15001         3    0.08   8.9986 -1.49700  3.5178  0.029548  0.002221
# 15002         3    0.12   9.0207 -1.54900  3.5177  0.007750 -0.017460
# 15003         3    0.16   9.0358 -1.51940  3.4881  0.006105  0.012988
# 15004         3    0.20   9.0357 -1.53430  3.5104  0.024155  0.003951
# ...         ...     ...      ...      ...     ...       ...       ...
# 1109995       4  299.84   7.4832  1.04130  2.7864  0.734120  0.374120
# 1109996       4  299.88   4.4419  0.88781  2.8071  0.867590  0.078475
# 1109997       4  299.92   4.5747 -3.16910  1.9164  0.544170 -0.654400
# 1109998       4  299.96   8.9999 -1.66530  2.2730 -0.216180 -1.398800
# 1109999       4  300.00  14.1350 -4.39120  3.0552  0.827890 -1.342200
#
#           T_zgyro   T_xmag   T_ymag  ...  RL_zmag  LL_xacc  LL_yacc  LL_zacc  \
# ...

# %%
# Making sure y-values are returning the appropriate amount of rows
print(y_train.shape)
print(y_test.shape)
# Out:
# (855000,)
# (285000,)

# %% [markdown]
# ## Seems like the data was randomly split 75% / 25% with my function
# ### Function returns:
# - X_train, X_test, y_train, y_test
# - random_values (the participants selected for training data)
